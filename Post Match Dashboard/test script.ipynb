# %%
import pandas as pd

# %%
df = pd.read_csv('Data/process_data/match_data21-09-23.csv')
data = df

# %%
centerbacks
# Out:
# array(['Ibrahima Konaté', 'Virgil van Dijk'], dtype=object)

# %%
fullbacks
# Out:
# array(['Kostas Tsimikas', 'Stefan Bajcetic'], dtype=object)

# %%
midfielders
# Out:
# array(['Harvey Elliott', 'Ryan Gravenberch', 'Wataru Endo'], dtype=object)

# %%
forwards
# Out:
# array(['Luis Díaz', 'Darwin Núñez', 'Ben Doak'], dtype=object)

# %%
data['position'].unique()
# Out:
# array([nan, 'MC', 'DC', 'DL', 'GK', 'DMR', 'DR', 'DML', 'FWR', 'FW',
#        'FWL', 'Sub'], dtype=object)

# %%
Home_cb = data[(data['teamId'] == 26) & (data['position'].isin(['DC']))]['playerName'].unique()

# %%
Home_cb
# Out:
# array(['Ibrahima Konaté', 'Virgil van Dijk'], dtype=object)

# %%
Home_cb = data[(data['Venue'] == 'Home') & (data['position'].isin(['DC']))]['playerName'].unique()
player_id = player_id_df[player_id_df['playerName'] == player_name]['playerId'].values[0]

for player_name in Home_cb:


fig = plt.figure(figsize=(15, 13), constrained_layout=True, dpi=600)
gs = fig.add_gridspec(ncols=3, nrows=3)  # change nrows from 2 to 3
fig.set_facecolor("#201D1D")

# create subplots using gridspec
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])  # add new subplot
ax4 = fig.add_subplot(gs[1, 0])
ax5 = fig.add_subplot(gs[1, 1])  # add new subplot
ax6 = fig.add_subplot(gs[1, 2])  # add new subplot

axes = [ax1, ax2, ax3, ax4, ax5, ax6]

# apply modifications to all subplots
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.grid(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.set_facecolor("#201D1D")
    ax.axis('off')

ax1.set_title('Offensive Actions', color='#e1dbd6', fontsize=16, pad=10)
ax4.set_title('Ball Carries', color='#e1dbd6', fontsize=16, pad=10)
ax3.set_title('Defensive Actions', color='#e1dbd6', fontsize=16, pad=10)
ax2.set_title('Territory map', color='#e1dbd6', fontsize=16, pad=10)
ax5.set_title('Pass Map', color='#e1dbd6', fontsize=16, pad=10)
ax6.set_title('Passes Receive ', color='#e1dbd6', fontsize=16, pad=10)

# fotmobvis.plot_player_shotmap(ax1,3901218,'Cody Gakpo')

whovis.plot_players_offensive_actions_opta(ax1, 'Trent Alexander-Arnold', offensive_actions, color='#1f8e98')
whovis.plot_carry_player_opta(ax4, 'Trent Alexander-Arnold', data)

whovis.plot_players_defensive_actions_opta(ax3, 'Trent Alexander-Arnold', defensive_actions, color='#1f8e98')

# whovis.plot_convex_hull_opta_player(ax2, 'Trent Alexander-Arnold', data)
whovis.plot_player_heatmap(ax2, data, 'Trent Alexander-Arnold', color='#1f8e98', sd=0)

whovis.plot_player_passmap_opta(ax5, 'Trent Alexander-Arnold', data)

whovis.plot_player_passes_rec_opta(ax6, 'Trent Alexander-Arnold', passes_df)

player_id = 760712
player_logo_path = f'Data/player_image/{player_id}.png'
club_icon = Image.open(player_logo_path).convert('RGBA')

logo_ax = fig.add_axes([0, .94, 0.12, 0.12], frameon=False)
logo_ax.imshow(club_icon)
logo_ax.set_xticks([])
logo_ax.set_yticks([])

fig.suptitle('Trent  Post Match Dashboard', fontsize=24, color='#e1dbd6', ha='center')

plt.savefig(
    f"figures/playerdashboard{player_id}.png",
    dpi=600,
    bbox_inches="tight",
    edgecolor="none",
    transparent=False
)

fig = plt.figure(figsize=(15, 13), constrained_layout=True, dpi=600)
gs = fig.add_gridspec(ncols=3, nrows=3)  # change nrows from 2 to 3
fig.set_facecolor("#201D1D")

# create subplots using gridspec
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])  # add new subplot
ax4 = fig.add_subplot(gs[1, 0])
ax5 = fig.add_subplot(gs[1, 1])  # add new subplot
ax6 = fig.add_subplot(gs[1, 2])  # add new subplot

axes = [ax1, ax2, ax3, ax4, ax5, ax6]

# apply modifications to all subplots
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.grid(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.set_facecolor("#201D1D")
    ax.axis('off')

ax1.set_title('Offensive Actions', color='#e1dbd6', fontsize=16, pad=10)
ax4.set_title('Ball Carries', color='#e1dbd6', fontsize=16, pad=10)
ax3.set_title('Defensive Actions', color='#e1dbd6', fontsize=16, pad=10)
ax2.set_title('Territory map', color='#e1dbd6', fontsize=16, pad=10)
ax5.set_title('Pass Map', color='#e1dbd6', fontsize=16, pad=10)
ax6.set_title('Passes Receive ', color='#e1dbd6', fontsize=16, pad=10)

whovis.plot_players_offensive_actions_opta(ax1, 'Jarell Quansah', offensive_actions, color='#1f8e98')
whovis.plot_carry_player_opta(ax4, 'Jarell Quansah', data)

whovis.plot_players_defensive_actions_opta(ax3, 'Jarell Quansah', defensive_actions, color='#1f8e98')

# whovis.plot_convex_hull_opta_player(ax2, 'Jarell Quansah', data)
whovis.plot_player_heatmap(ax2, data, 'Jarell Quansah', color='#1f8e98', sd=0)

whovis.plot_player_passmap_opta(ax5, 'Jarell Quansah', data)

whovis.plot_player_passes_rec_opta(ax6, 'Jarell Quansah', passes_df)

player_id = 1107620
player_logo_path = f'Data/player_image/{player_id}.png'
club_icon = Image.open(player_logo_path).convert('RGBA')

logo_ax = fig.add_axes([0, .94, 0.12, 0.12], frameon=False)
logo_ax.imshow(club_icon)
logo_ax.set_xticks([])
logo_ax.set_yticks([])

fig.suptitle('Jarell Quansah  Post Match Dashboard', fontsize=24, color='#e1dbd6', ha='center')

plt.savefig(
    f"figures/playerdashboard{player_id}.png",
    dpi=600,
    bbox_inches="tight",
    edgecolor="none",
    transparent=False
)
# Out:
# array([nan, 'MC', 'DC', 'DL', 'GK', 'DR', 'FWL', 'FW', 'FWR', 'Sub'],
#       dtype=object)

# %%
positions = df[df['teamId']==26]['position'].unique()

for position in positions:
    player_name = positions[positions['position'] == position]['playerName']  # Assuming there is only one player per position
    print(player_name)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [9], line 4
#       1 positions = df[df['teamId']==26]['position'].unique()
#       3 for position in positions:
# ----> 4     player_name = positions[positions['position'] == position]['playerName']  # Assuming there is only one player per position
#       5     print(player_name)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import pandas as pd
import sqlalchemy


from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Liverpool19@localhost:5432/soccer')


conn = engine.connect()
if current_competition == 'Premier League':
    shots_query = "SELECT * FROM fotmob_shots_data WHERE match_date = current_date AND (teamId = 8650 OR matchId IN (SELECT matchId FROM fotmob_shots_data WHERE teamId = 8650)) AND competition = 'Premier League'"
    comp_name = 'Premier League'
else:
    shots_query = "SELECT * FROM fotmob_shots_data WHERE match_date = current_date AND (teamId = 8650 OR matchId IN (SELECT matchId FROM fotmob_shots_data WHERE teamId = 8650))"
    comp_name = 'All Competition'

# Query the database and load data into a DataFrame
shots_data = pd.read_sql(shots_query, conn)


if current_competition == 'Premier League':
    query = "SELECT * FROM opta_event_data WHERE match_date = current_date AND (teamId = 8650 OR matchId IN (SELECT matchId FROM opta_event_data WHERE teamId = 8650)) AND competition = 'Premier League'"
    comp_name = 'Premier League'
else:
    query = "SELECT * FROM opta_event_data WHERE match_date = current_date AND (teamId = 8650 OR matchId IN (SELECT matchId FROM opta_event_data WHERE teamId = 8650))"
    comp_name = 'All Competition'

# Query the database and load data into a DataFrame
data = pd.read_sql(query, conn)






# Rest of your code

# Assuming comp_name is used in your figure text
fig_text(
    0.4,
    0.84,
    f'Compared to Liverpool\'s {comp_name} Average since the start of the 2023/24 season',
    fontsize=3,
    color="#FCE6E6",
    ha="center",
    va="center",
)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mplsoccer import Pitch
from mplsoccer import VerticalPitch
import sqlite3
from highlight_text import fig_text, ax_text
import matplotlib

from matplotlib.colors import LinearSegmentedColormap

from PIL import Image

from Football_Analysis_Tools import whoscored_visuals as whovis

from Football_Analysis_Tools import odds
from Football_Analysis_Tools import fotmob_visuals as fmvis

con = sqlite3.connect("../Database/EPL_event_data_23_24.db")
cur = con.cursor()

data = pd.read_sql("Select * from Match Where match_date = current_date", con)

data = data[data['is_open_play'] == True]
data = data[data['outcomeType'] == 'Successful']

event_home_df = data[data['Venue'] == 'Home']
event_away_df = data[data['Venue'] == 'Away']

opta_matchID = data['match_id'].iloc[0]

opta_home_teamID = event_home_df['teamId'].iloc[0]
opta_away_teamID = event_away_df['teamId'].iloc[0]

conn = sqlite3.connect("../Database/EPL23_24.db")

cur_1 = conn.cursor()

# shots_data = pd.read_sql("Select * from Shots_data Where match_date = current_date and (TeamName = 'Liverpool')", conn)

shots_data = pd.read_sql(
    "SELECT * FROM Shots_data WHERE match_date = current_date AND (teamId = 8650 OR matchId IN (SELECT matchId FROM Shots_data WHERE teamId = 8650))",
    conn)

Fotmob_matchID = shots_data['matchId'].iloc[0]

Fotmob_homeID = shots_data[shots_data['Venue'] == 'Home']
Fotmob_awayID = shots_data[shots_data['Venue'] == 'Away']
Fotmob_homeID = Fotmob_homeID['teamId'].iloc[0]
Fotmob_awayID = Fotmob_awayID['teamId'].iloc[0]

import requests
import json


def get_match_label(match_id):
    response = requests.get(f'https://www.fotmob.com/api/matchDetails?matchId={match_id}')
    data = json.loads(response.content)
    general = data['general']
    leagueName = general['leagueName']
    leagueRoundName = general['leagueRoundName']
    return leagueName + " " + leagueRoundName


def get_match_season(match_id):
    response = requests.get(f'https://www.fotmob.com/api/matchDetails?matchId={match_id}')
    data = json.loads(response.content)
    general = data['general']
    parentLeagueSeason = general['parentLeagueSeason']
    return parentLeagueSeason


match_season = get_match_season(Fotmob_matchID)


def get_match_date(match_id):
    response = requests.get(f'https://www.fotmob.com/api/matchDetails?matchId={match_id}')
    data = json.loads(response.content)
    general = data['general']
    matchDate = general['matchTimeUTCDate']
    matchDate = matchDate.split('T')[0]

    return matchDate


matchDate = get_match_date(Fotmob_matchID)


def get_match_name(match_id):
    response = requests.get(f'https://www.fotmob.com/api/matchDetails?matchId={match_id}')
    data = json.loads(response.content)
    general = data['general']
    Hteam = general['homeTeam']
    Ateam = general['awayTeam']
    Hteam = Hteam['name']
    Ateam = Ateam['name']
    return Hteam + " " + "vs" + " " + Ateam


match_name = get_match_name(Fotmob_matchID)


def get_match_score(match_id):
    response = requests.get(f'https://www.fotmob.com/api/matchDetails?matchId={match_id}')
    data = json.loads(response.content)
    match_score = data['header']['status']['scoreStr']
    return match_score


match_score = get_match_score(Fotmob_matchID)
match_label = get_match_label(Fotmob_matchID)

home = data[data['teamId'] == opta_home_teamID]
away = data[data['teamId'] == opta_away_teamID]

# colors = ["#29222c","#32283b","#3b2d4b","#44335a","#4c3869","#553e78","#5e4388","#674997","#704ea6"]

colors = ["#264653", "#2a9d8f", "#e9c46a", "#f4a261", "#e76f51"]

passnetwork_cmap = LinearSegmentedColormap.from_list('passnetwork', colors, N=250)
plt.cm.register_cmap(name='passnetwork', cmap=passnetwork_cmap)

homecolor = '#FDB913'
awaycolor = '#1A6158'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 121
#     118 colors = ["#264653", "#2a9d8f", "#e9c46a", "#f4a261", "#e76f51"]
#     120 passnetwork_cmap = LinearSegmentedColormap.from_list('passnetwork', colors, N=250)
# --> 121 plt.cm.register_cmap(name='passnetwork', cmap=passnetwork_cmap)
#     123 homecolor = '#FDB913'
#     124 awaycolor = '#1A6158'
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:200, in deprecated.<locals>.deprecate.<locals>.wrapper(*args, **kwargs)
#     198 def wrapper(*args, **kwargs):
#     199     emit_warning()
# --> 200     return func(*args, **kwargs)
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/matplotlib/cm.py:248, in register_cmap(name, cmap, override_builtin)
#     244 # override_builtin is allowed here for backward compatibility
#     245 # this is just a shim to enable that to work privately in
#     246 # the global ColormapRegistry
#     247 _colormaps._allow_override_builtin = override_builtin
# --> 248 _colormaps.register(cmap, name=name, force=override_builtin)
#     249 _colormaps._allow_override_builtin = False
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/matplotlib/cm.py:149, in ColormapRegistry.register(self, cmap, name, force)
#     145 if name in self:
#     146     if not force:
#     147         # don't allow registering an already existing cmap
#     148         # unless explicitly asked to
# --> 149         raise ValueError(
#     150             f'A colormap named "{name}" is already registered.')
#     151     elif (name in self._builtin_cmaps
#     152             and not self._allow_override_builtin):
#     153         # We don't allow overriding a builtin unless privately
#     154         # coming from register_cmap()
#     155         raise ValueError("Re-registering the builtin cmap "
#     156                          f"{name!r} is not allowed.")
#
# ValueError: A colormap named "passnetwork" is already registered.

# %%
home_name = home['team_name'].iloc[0]
away_name = away['team_name'].iloc[0]

# %%
def find_offensive_actions(events_df):
    # Define and filter offensive events
    offensive_actions = ['TakeOn', 'MissedShots', 'SavedShot', 'Goal','ShotOnPost', 'Carry']
    offensive_action_df = events_df[events_df['event_type'].isin(offensive_actions)].reset_index(drop=True)

    # Filter for passes made by goalkeepers
    pass_gk = events_df[(events_df['event_type'] == 'Pass') & (events_df['position'] == 'GK')]

    # Filter for passes with assists or pre-assists
    pass_df = events_df[(events_df['event_type'] == 'Pass') & ((events_df['assist'] == True) | (events_df['pre_assist'] == True))]

    # Concatenate offensive actions and passes with assists or pre-assists
    offensive_actions_df = pd.concat([offensive_action_df, pass_df, pass_gk]).reset_index(drop=True)

    return offensive_actions_df

def find_defensive_actions(events_df):
    """ Return dataframe of in-play defensive actions from event data.
    Function to find all in-play defensive actions within a whscored-style events dataframe (single or multiple
    matches), and return as a new dataframe.
    Args:
        events_df (pandas.DataFrame): whoscored-style dataframe of event data. Events can be from multiple matches.
    Returns:
        pandas.DataFrame: whoscored-style dataframe of defensive actions.
    """

    # Define and filter defensive events
    defensive_actions = ['BallRecovery', 'BlockedPass', 'Challenge', 'Clearance', 'Interception', 'Tackle',
                         'Claim', 'KeeperPickup', 'Punch', 'Save','BlockedPass','Aerial']
    defensive_action_df = events_df[events_df['event_type'].isin(defensive_actions)]

    return defensive_action_df

# %%
offensive_actions = find_offensive_actions(data)
defensive_actions = find_defensive_actions(data)

# %%
def get_player_dfs(data):
    player_dfs = {}

    for player_name in data['playerName'].dropna().unique():
        player_df = data[data['playerName'] == player_name].copy()

        x_avg = player_df['x'].mean()
        y_avg = player_df['y'].mean()

        player_df['x_avg'] = x_avg
        player_df['y_avg'] = y_avg

        initials = player_name.split()[0][0] + player_name.split()[-1][0]
        player_df['initials'] = initials

        player_dfs[player_name] = player_df

    return player_dfs


player_offensive_actions = get_player_dfs(offensive_actions)

player_dfs = get_player_dfs(defensive_actions)

Home_gk = data[(data['Venue'] == 'Home') & (data['position'].isin(['GK']))]['playerName'].unique()
Home_cb = data[(data['Venue'] == 'Home') & (data['position'].isin(['DC']))]['playerName'].unique()
Home_fullbacks = data[(data['Venue'] == 'Home') & (data['position'].isin(['DL', 'DR']))]['playerName'].unique()
Home_midfielders = data[(data['Venue'] == 'Home') & (data['position'].isin(['DMC', 'AMC', 'MC']))][
    'playerName'].unique()
Home_attackers = data[(data['Venue'] == 'Home') & (data['position'].isin(['FWR', 'FWL', 'AML', 'AMR', 'FW']))][
    'playerName'].unique()
Home_sub = data[(data['Venue'] == 'Home') & (data['position'].isin(['Sub']))]['playerName'].unique()

Away_gk = data[(data['Venue'] == 'Away') & (data['position'].isin(['GK']))]['playerName'].unique()
Away_cb = data[(data['Venue'] == 'Away') & (data['position'].isin(['DC']))]['playerName'].unique()
Away_fullbacks = data[(data['Venue'] == 'Away') & (data['position'].isin(['DL', 'DR']))]['playerName'].unique()
Away_midfielders = data[(data['Venue'] == 'Away') & (data['position'].isin(['DMC', 'AMC', 'MC']))][
    'playerName'].unique()
Away_attackers = data[(data['Venue'] == 'Away') & (data['position'].isin(['FWR', 'FWL', 'AML', 'AMR', 'FW']))][
    'playerName'].unique()
Away_sub = data[(data['Venue'] == 'Away') & (data['position'].isin(['Sub']))]['playerName'].unique()

# %%
from sqlalchemy import create_engine


engine = create_engine('postgresql://postgres:Liverpool19@localhost:5432/soccer')
conn = engine.connect()

# %%
match_date = '2023-10-05'
import pandas as pd
current_competition = 'Europa League'

# %%
# Assuming you have a date variable called 'match_date'
# Modify this variable according to your specific use case

# Step 1: Filter matches by date for opta_event_data
opta_matches_query = f"""SELECT * FROM opta_event_data 
                         WHERE "match_date" = '{match_date}'"""

# Query the database and load data into a DataFrame
opta_matches_data = pd.read_sql(opta_matches_query, conn)

# Check if there are matches for the given date
if not opta_matches_data.empty:
    # Step 2: Determine the competition for the selected match
    opta_comp_name = opta_matches_data['competition'].iloc[0]  # Assuming 'competition' is the column name

    # Step 3: Retrieve the rest of the matches for that competition in opta_event_data
    if current_competition == 'Premier League':
        opta_query = f"""SELECT * FROM opta_event_data 
                         WHERE competition = 'Premier League'"""
    else current_competition != 'Premier League':
        opta_query = f"""SELECT * FROM opta_event_data 
                         WHERE  competition = '{opta_comp_name}'"""

    # Query the database and load data into a DataFrame
    opta_data = pd.read_sql(opta_query, conn)
else:
    opta_comp_name = None  # No matches found for the given date in opta_event_data

# Now, 'opta_data' contains the matches for the determined competition in opta_event_data
# 'opta_comp_name' contains the name of the competition for the selected match in opta_event_data (or None if no matches were found)

# %%
opta_matches_data['match_date'].unique()
# Out:
# array(['2023-10-05'], dtype=object)

# %%
# Step 1: Filter matches by date
matches_query = f"""SELECT * FROM fotmob_shots_data 
                    WHERE "match_date" = '{match_date}'"""

# Query the database and load data into a DataFrame
matches_data = pd.read_sql(matches_query, conn)

# Check if there are matches for the given date
if not matches_data.empty:
    # Step 2: Determine the competition for the selected match
    comp_name = matches_data['competition'].iloc[0]  # Assuming 'competition' is the column name

    # Step 3: Retrieve all matches for that competition
    if competition == 'Premier League':
        shots_query = f"""SELECT * FROM fotmob_shots_data 
                          WHERE competition = f'{comp_name}'"""
    else:
        shots_query = f"""SELECT * FROM fotmob_shots_data"""

    # Query the database and load data into a DataFrame
    shots_data = pd.read_sql(shots_query, conn)
else:
    comp_name = None  # No matches found for the given date
NameError: name 'competition' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [44], line 14
#      11 comp_name = matches_data['competition'].iloc[0]  # Assuming 'competition' is the column name
#      13 # Step 3: Retrieve all matches for that competition
# ---> 14 if competition == 'Premier League':
#      15     shots_query = f"""SELECT * FROM fotmob_shots_data
#      16                       WHERE competition = f'{comp_name}'"""
#      17 else:
#
# NameError: name 'competition' is not defined

# %%
shots_data['match_date'].unique()
# Out:
# array(['2023-08-13', '2023-08-19', '2023-08-27', '2023-09-03',
#        '2023-09-16', '2023-09-24', '2023-09-21', '2023-10-21',
#        '2023-09-27', '2023-09-30', '2023-10-05', '2023-10-08'],
#       dtype=object)

# %%
shots_data['competition'].unique()
# Out:
# array(['Premier League', 'Europa League', 'EFL Cup'], dtype=object)

# %%
shots_data[shots_data['match_date']==match_date]&.iloc[0]['match_id']
# Out:
# '4315083'

# %%
shots_data[shots_data['match_date']==match_date][shots_data['teamId']==8650].iloc[0]['match_id']
/var/folders/vp/bmgsm3216fg61zdd22k8n6jw0000gn/T/ipykernel_11149/1902245211.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
shots_data[shots_data['match_date']==match_date][shots_data['teamId']==8650].iloc[0]['match_id']
# Out:
# /var/folders/vp/bmgsm3216fg61zdd22k8n6jw0000gn/T/ipykernel_11149/1902245211.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   shots_data[shots_data['match_date']==match_date][shots_data['teamId']==8650].iloc[0]['match_id']
# '4315083'

# %%
shots_data.loc[(shots_data['match_date'] == match_date) & (shots_data['teamId'] == 8650), 'match_id'].iloc[0]
# Out:
# '4315083'

# %%
fig = plt.figure(figsize=(12, 8), constrained_layout=True, dpi=300)
gs = fig.add_gridspec(ncols=2, nrows=2)
fig.set_facecolor("#201D1D")
# create subplots using gridspec
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])

axes = [ax1, ax2, ax3, ax4]

# apply modifications to all subplots
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.grid(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.set_facecolor("#201D1D")


for player in Home_gk:
    player_df = player_dfs[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax1, poly_edgecolor='#44335a', poly_facecolor='#44335a',
                                     scatter_facecolor='#44335a', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Home_gk:
    player_df = player_offensive_actions[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax3, poly_edgecolor='#44335a', poly_facecolor='#44335a',
                                     scatter_facecolor='#44335a', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Home_cb:
    player_df = player_dfs[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax1, poly_edgecolor='#674997', poly_facecolor='#674997',
                                     scatter_facecolor='#674997', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Home_cb:
    player_df = player_offensive_actions[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax3, poly_edgecolor='#674997', poly_facecolor='#674997',
                                     scatter_facecolor='#674997', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Home_fullbacks:
    player_df = player_dfs[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax1, poly_edgecolor='#007a72', poly_facecolor='#007a72',
                                     scatter_facecolor='#007a72', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Home_fullbacks:
    player_df = player_offensive_actions[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax3, poly_edgecolor='#007a72', poly_facecolor='#007a72',
                                     scatter_facecolor='#007a72', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Home_midfielders:
    player_df = player_dfs[player]
    if not player_df.empty and len(player_df) > 3:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax1, poly_edgecolor='#d1495b', poly_facecolor='#d1495b',
                                     scatter_facecolor='#d1495b', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")



for player in Home_midfielders:
    player_df = player_offensive_actions[player]
    if not player_df.empty and len(player_df) > 3:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax3, poly_edgecolor='#d1495b', poly_facecolor='#d1495b',
                                     scatter_facecolor='#d1495b', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Home_attackers:
    player_df = player_dfs[player]
    if not player_df.empty and len(player_df) > 3:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax1, poly_edgecolor='#edae49', poly_facecolor='#edae49',
                                     scatter_facecolor='#edae49', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Home_attackers:
    player_df = player_offensive_actions[player]
    if not player_df.empty and len(player_df) > 3:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax3, poly_edgecolor='#edae49', poly_facecolor='#edae49',
                                     scatter_facecolor='#edae49', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")


for player in Away_gk:
    player_df = player_dfs[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax2, poly_edgecolor='#44335a', poly_facecolor='#44335a',
                                     scatter_facecolor='#44335a', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Away_gk:
    player_df = player_offensive_actions[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax4, poly_edgecolor='#44335a', poly_facecolor='#44335a',
                                     scatter_facecolor='#44335a', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Away_cb:
    player_df = player_dfs[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax2, poly_edgecolor='#674997', poly_facecolor='#674997',
                                     scatter_facecolor='#674997', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Away_cb:
    player_df = player_offensive_actions[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax4, poly_edgecolor='#674997', poly_facecolor='#674997',
                                     scatter_facecolor='#674997', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Away_fullbacks:
    player_df = player_dfs[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax2, poly_edgecolor='#007a72', poly_facecolor='#007a72',
                                     scatter_facecolor='#007a72', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Away_fullbacks:
    player_df = player_offensive_actions[player]
    if not player_df.empty:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax4, poly_edgecolor='#007a72', poly_facecolor='#007a72',
                                     scatter_facecolor='#007a72', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Away_midfielders:
    player_df = player_dfs[player]
    if not player_df.empty and len(player_df) > 3:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax2, poly_edgecolor='#d1495b', poly_facecolor='#d1495b',
                                     scatter_facecolor='#d1495b', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")



for player in Away_midfielders:
    player_df = player_offensive_actions[player]
    if not player_df.empty and len(player_df) > 3:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax4, poly_edgecolor='#d1495b', poly_facecolor='#d1495b',
                                     scatter_facecolor='#d1495b', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Away_attackers:
    player_df = player_dfs[player]
    if not player_df.empty and len(player_df) > 3:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax2, poly_edgecolor='#edae49', poly_facecolor='#edae49',
                                     scatter_facecolor='#edae49', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")

for player in Away_attackers:
    player_df = player_offensive_actions[player]
    if not player_df.empty and len(player_df) > 3:  # check if there are at least 5 points for the player
        whovis.plot_player_hull_team(player_df, ax4, poly_edgecolor='#edae49', poly_facecolor='#edae49',
                                     scatter_facecolor='#edae49', avg_marker_size=200, sd=2)
    else:
        print(f"Not enough points for {player}. Skipping...")



ax1.set_title(f"{home_name} Territory Map Defensive Actions",size="6", c="#EFE9F4", loc="center")
ax2.set_title(f"{away_name} Territory Map Offensive Actions",size="6", c="#EFE9F4", loc="center")

ax3.set_title(f"{home_name} Territory Map Defensive Actions",size="6", c="#EFE9F4", loc="center")
ax4.set_title(f"{away_name} Territory Map Offensive Actions",size="6", c="#EFE9F4", loc="center")



team_logo_path = f'Data/team_logo/{Fotmob_homeID}.png'
club_icon = Image.open(team_logo_path).convert('RGBA')


away_team_logo_path = f'Data/team_logo/{Fotmob_awayID}.png'
away_club_icon = Image.open(away_team_logo_path).convert('RGBA')

away_logo_ax = fig.add_axes([.90, 1, .1, .10], frameon=False)


away_logo_ax.imshow(away_club_icon, aspect='equal')
away_logo_ax.axis('off')

away_logo_ax.set_xticks([])
away_logo_ax.set_yticks([])


logo_ax = fig.add_axes([0, 1, 0.1, 0.10], frameon=False)
logo_ax.imshow(club_icon, aspect='equal')
logo_ax.set_xticks([])
logo_ax.set_yticks([])


ax = fig.add_axes([.45, 1, .1, .14], frameon=False)

# add the text to the Axes object using ax_text
fig_text(
    0.5,
    0.78,
    match_score,
    fontsize=9,
    color="#FCE6E6",
    ha="center",
    va="center",
    transform=ax.transAxes
)

fig_text(
    0.5,
    0.74,
    match_name,
    fontsize=7,
    color="#FCE6E6",
    ha="center",
    va="center",
    transform=ax.transAxes
)

# finally, turn off the visibility of the Axes object
ax.set_axis_off()


# fig.savefig(f"figures/dashboardTerritory_Map{matchDate}.png", dpi=700, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [14], line 53
#      51 player_df = player_offensive_actions[player]
#      52 if not player_df.empty:  # check if there are at least 5 points for the player
# ---> 53     whovis.plot_player_hull_team(player_df, ax3, poly_edgecolor='#674997', poly_facecolor='#674997',
#      54                                  scatter_facecolor='#674997', avg_marker_size=200, sd=2)
#      55 else:
#      56     print(f"Not enough points for {player}. Skipping...")
#
# File ~/Documents/Coding Projects/Soccer Coding Projects/Football_Analysis_Tools/whoscored_visuals.py:352, in plot_player_hull_team(player_df, ax, poly_edgecolor, poly_facecolor, poly_alpha, scatter_edgecolor, scatter_facecolor, avg_marker_size, sd)
#     350 pitch = Pitch()
#     351 # Draw convex hull polygon
# --> 352 hull = pitch.convexhull(new_player_df.x, new_player_df.y)
#     353 poly = pitch.polygon(hull, ax=ax, edgecolor=poly_edgecolor, facecolor=poly_facecolor, alpha=poly_alpha)
#     355 # Draw scatter plot
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/mplsoccer/_pitch_plot.py:506, in BasePitchPlot.convexhull(self, x, y)
#     483 """ Get lines of Convex Hull for a set of coordinates
#     484
#     485 Parameters
#    (...)
#     503 >>> poly = pitch.polygon(hull, ax=ax, facecolor='cornflowerblue', alpha=0.3)
#     504 """
#     505 points = np.vstack([x, y]).T
# --> 506 hull = ConvexHull(points)
#     507 return points[hull.vertices].reshape(1, -1, 2)
#
# File _qhull.pyx:2448, in scipy.spatial._qhull.ConvexHull.__init__()
#
# File _qhull.pyx:281, in scipy.spatial._qhull._Qhull.__init__()
#
# ValueError: No points given

# %%
from PIL import Image
from sklearn.cluster import KMeans
import numpy as np
import requests
from io import BytesIO

def get_dominant_colors_from_url(image_url, n_colors=2):
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content))
    image = image.resize((100, 100))  # Resize the image for faster processing
    pixels = np.array(image).reshape(-1, 3)

    kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(pixels)
    colors = kmeans.cluster_centers_

    return colors.astype(int)

# Example usage
image_url = "https://images.fotmob.com/image_resources/logo/teamlogo/8650.png"
dominant_colors = get_dominant_colors_from_url(image_url)

print("Dominant Colors:")
for color in dominant_colors:
    print(color)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [2], line 20
#      18 # Example usage
#      19 image_url = "https://images.fotmob.com/image_resources/logo/teamlogo/8650.png"
# ---> 20 dominant_colors = get_dominant_colors_from_url(image_url)
#      22 print("Dominant Colors:")
#      23 for color in dominant_colors:
#
# Cell In [2], line 11, in get_dominant_colors_from_url(image_url, n_colors)
#       9 image = Image.open(BytesIO(response.content))
#      10 image = image.resize((100, 100))  # Resize the image for faster processing
# ---> 11 pixels = np.array(image).reshape(-1, 3)
#      13 kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(pixels)
#      14 colors = kmeans.cluster_centers_
#
# ValueError: cannot reshape array of size 10000 into shape (3)

# %%
import requests
from PIL import Image
from sklearn.cluster import KMeans
import numpy as np
from io import BytesIO

def get_dominant_colors_from_url(image_url, n_colors=2):
    # Download the image from the URL
    response = requests.get(image_url)
    if response.status_code == 200:
        image_data = response.content
    else:
        raise Exception("Failed to fetch the image from the URL")

    image = Image.open(BytesIO(image_data))
    image = image.resize((100, 100))  # Resize the image for faster processing
    pixels = np.array(image).reshape(-1, 3)

    kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(pixels)
    colors = kmeans.cluster_centers_

    return colors.astype(int)

# Example usage
image_url = "https://images.fotmob.com/image_resources/logo/teamlogo/8650.png"
dominant_colors = get_dominant_colors_from_url(image_url)

print("Dominant Colors:")
for color in dominant_colors:
    print(color)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 26
#      24 # Example usage
#      25 image_url = "https://images.fotmob.com/image_resources/logo/teamlogo/8650.png"
# ---> 26 dominant_colors = get_dominant_colors_from_url(image_url)
#      28 print("Dominant Colors:")
#      29 for color in dominant_colors:
#
# Cell In [3], line 17, in get_dominant_colors_from_url(image_url, n_colors)
#      15 image = Image.open(BytesIO(image_data))
#      16 image = image.resize((100, 100))  # Resize the image for faster processing
# ---> 17 pixels = np.array(image).reshape(-1, 3)
#      19 kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(pixels)
#      20 colors = kmeans.cluster_centers_
#
# ValueError: cannot reshape array of size 10000 into shape (3)

# %%
from PIL import Image
import requests
import numpy as np

def get_dominant_colors_from_url(image_url, n_colors=2):
    # Download the image from the URL
    response = requests.get(image_url)
    if response.status_code == 200:
        image_data = response.content
    else:
        raise Exception("Failed to fetch the image from the URL")

    image = Image.open(BytesIO(image_data))
    image = image.resize((100, 100))  # Resize the image for faster processing

    # Convert the image to RGB mode if it's not already
    image = image.convert("RGB")

    # Get the image data as a NumPy array
    pixels = np.array(image)

    # Reshape the array to a 2D array of RGB values
    pixels = pixels.reshape(-1, 3)

    # Calculate the histogram of colors
    hist, _ = np.histogramdd(pixels, bins=(16, 16, 16), range=((0, 256), (0, 256), (0, 256)))

    # Get the indices of the most frequent colors
    dominant_color_indices = np.unravel_index(np.argmax(hist), hist.shape)

    # Convert the indices to RGB values
    dominant_colors = np.array(dominant_color_indices).reshape(1, -1)

    return dominant_colors

# Example usage
image_url = "https://images.fotmob.com/image_resources/logo/teamlogo/8650.png"
dominant_colors = get_dominant_colors_from_url(image_url)

print("Dominant Colors:")
for color in dominant_colors:
    print(color)
# Out:
# Dominant Colors:
# [0 0 0]
# /Users/andrew/Documents/Coding Projects/lib/python3.9/site-packages/PIL/Image.py:979: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
